# %% [markdown]
# # D212 Assessment 3

# %% [markdown]
# #### Import relevant packages

# %%
# Pandas for operation of dataframes
import pandas as pd

import math

# Import permutations from the itertools module
from itertools import permutations

# Import the transaction encoder function from mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Read in dataset as dataframe with pandas read_csv function
teleco_df = pd.read_csv('teleco_market_basket.csv')

# %%
# Visualize the head of the dataset with pandas head function
teleco_df.head()
# Out:
#                                   Item01                            Item02  \
# 0                                    NaN                               NaN
# 1           Logitech M510 Wireless mouse                         HP 63 Ink
# 2                                    NaN                               NaN
# 3  Apple Lightning to Digital AV Adapter  TP-Link AC1750 Smart WiFi Router
# 4                                    NaN                               NaN
#
#          Item03                      Item04                     Item05  \
# 0           NaN                         NaN                        NaN
# 1     HP 65 ink  nonda USB C to USB Adapter  10ft iPHone Charger Cable
# 2           NaN                         NaN                        NaN
# 3  Apple Pencil                         NaN                        NaN
# 4           NaN                         NaN                        NaN
#
#          Item06                        Item07  \
# 0           NaN                           NaN
# 1  HP 902XL ink  Creative Pebble 2.0 Speakers
# 2           NaN                           NaN
# 3           NaN                           NaN
# 4           NaN                           NaN
#
#                                 Item08                         Item09  \
# 0                                  NaN                            NaN
# 1  Cleaning Gel Universal Dust Cleaner  Micro Center 32GB Memory card
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#                                     Item10                        Item11  \
# 0                                      NaN                           NaN
# 1  YUNSONG 3pack 6ft Nylon Lightning Cable  TopMate C5 Laptop Cooler pad
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#                       Item12                        Item13  \
# 0                        NaN                           NaN
# 1  Apple USB-C Charger cable  HyperX Cloud Stinger Headset
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#                         Item14                          Item15  \
# 0                          NaN                             NaN
# 1  TONOR USB Gaming Microphone  Dust-Off Compressed Gas 2 pack
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#                            Item16                 Item17  \
# 0                             NaN                    NaN
# 1  3A USB Type C Cable 3 pack 6FT  HOVAMP iPhone charger
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
#                      Item18                                Item19  \
# 0                       NaN                                   NaN
# 1  SanDisk Ultra 128GB card  FEEL2NICE 5 pack 10ft Lighning cable
# 2                       NaN                                   NaN
# 3                       NaN                                   NaN
# 4                       NaN                                   NaN
#
#                                 Item20
# 0                                  NaN
# 1  FEIYOLD Blue light Blocking Glasses
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
# Remove completely null records
teleco_df = teleco_df.dropna(subset=['Item01'])

# %%
teleco_df = teleco_df.reset_index(drop=True)
teleco_df.insert(0, 'Basket_id', range(1, 1 + len(teleco_df)))

# %%
basket_id_list = []
item_list = []
cnt_list = []

for col in teleco_df.columns[1:]:
    for i in range(1, len(teleco_df)):
        if teleco_df[col].isnull().iloc[i,]==False:
            basket_id_list.append(teleco_df['Basket_id'].iloc[i,])
            item_list.append(teleco_df[col].iloc[i,])
            cnt_list.append(1)

# %%
basket_df = pd.DataFrame()
basket_df['Basket_id'] = basket_id_list
basket_df['Item desc'] = item_list
basket_df['Cnt'] = 1

# %%
basket_grp = (basket_df.groupby(['Basket_id', 'Item desc'])['Cnt'].sum().unstack().reset_index().fillna(0).set_index('Basket_id'))

# %%
def normalize(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_enc = basket_grp.applymap(normalize)

basket_std = basket_enc[(basket_enc > 0).sum(axis=1) >= 2]

# %%
print(basket_std.shape)
# Out:
# (5746, 119)

# %%
basket_std.head()
# Out:
# Item desc  10ft iPHone Charger Cable  10ft iPHone Charger Cable 2 Pack  \
# Basket_id
# 2                                  0                                 0
# 4                                  0                                 0
# 5                                  0                                 0
# 7                                  0                                 0
# 8                                  0                                 1
#
# Item desc  3 pack Nylon Braided Lightning Cable  \
# Basket_id
# 2                                             0
# 4                                             0
# 5                                             0
# 7                                             0
# 8                                             0
#
# Item desc  3A USB Type C Cable 3 pack 6FT  5pack Nylon Braided USB C cables  \
# Basket_id
# 2                                       0                                 0
# 4                                       0                                 0
# 5                                       0                                 0
# 7                                       0                                 0
# 8                                       0                                 0
#
# Item desc  ARRIS SURFboard SB8200 Cable Modem  Anker 2-in-1 USB Card Reader  \
# Basket_id
# 2                                           0                             0
# 4                                           0                             0
# 5                                           0                             0
# 7                                           0                             1
# 8                                           0                             0
#
# Item desc  Anker 4-port USB hub  Anker USB C to HDMI Adapter  \
# Basket_id
# 2                             0                            0
# 4                             0                            0
# 5                             0                            0
# 7                             0                            0
# 8                             0                            0
#
# Item desc  Apple Lightning to Digital AV Adapter  ...  hP 65 Tri-color ink  \
# Basket_id                                         ...
# 2                                              1  ...                    0
# 4                                              0  ...                    0
# 5                                              0  ...                    0
# 7                                              0  ...                    0
# 8                                              0  ...                    0
#
# Item desc  iFixit Pro Tech Toolkit  iPhone 11 case  iPhone 12 Charger cable  \
# Basket_id
# 2                                0               0                        0
# 4                                0               0                        0
# 5                                0               0                        0
# 7                                0               0                        0
# 8                                0               0                        0
#
# Item desc  iPhone 12 Pro case  iPhone 12 case  iPhone Charger Cable Anker 6ft  \
# Basket_id
# 2                           0               0                               0
# 4                           0               0                               0
# 5                           0               0                               0
# 7                           0               0                               0
# 8                           0               0                               0
#
# Item desc  iPhone SE case  nonda USB C to USB Adapter  seenda Wireless mouse
# Basket_id
# 2                       0                           0                      0
# 4                       0                           0                      0
# 5                       0                           0                      0
# 7                       0                           0                      0
# 8                       0                           0                      0
#
# [5 rows x 119 columns]

# %%
pd.set_option('display.max_rows', None)
support = basket_std.mean()

# %%
print(support.sort_values(ascending=False))
# Out:
# Item desc
# Dust-Off Compressed Gas 2 pack                0.294814
# Apple Pencil                                  0.218935
# VIVO Dual LCD Monitor Desk mount              0.218239
# HP 61 ink                                     0.201183
# USB 2.0 Printer cable                         0.200139
# Screen Mom Screen Cleaner kit                 0.163418
# Apple USB-C Charger cable                     0.159763
# SanDisk Ultra 64GB card                       0.124608
# Nylon Braided Lightning to USB cable          0.121128
# Stylus Pen for iPad                           0.117299
# Apple Lightning to Digital AV Adapter         0.110338
# Syntech USB C to USB Adapter                  0.100766
# TopMate C5 Laptop Cooler pad                  0.091890
# Logitech M510 Wireless mouse                  0.090672
# Anker USB C to HDMI Adapter                   0.085973
# HP 63XL Ink                                   0.085973
# FEIYOLD Blue light Blocking Glasses           0.081796
# Cat8 Ethernet Cable                           0.079360
# SanDisk Ultra 128GB card                      0.079011
# Falcon Dust Off Compressed Gas                0.076575
# HP 62XL Tri-Color ink                         0.073268
# USB Type C to USB-A Charger cable             0.066133
# Premium Nylon USB Cable                       0.065437
# SAMSUNG EVO 32GB card                         0.064741
# 10ft iPHone Charger Cable 2 Pack              0.064567
# SanDisk 128GB Ultra microSDXC card            0.060912
# HyperX Cloud Stinger Headset                  0.060738
# SanDisk 128GB microSDXC card                  0.054125
# 3A USB Type C Cable 3 pack 6FT                0.053428
# USB Type C Cable                              0.053254
# HP 65 ink                                     0.042116
# HOVAMP Mfi 6pack Lightning Cable              0.040898
# Cleaning Gel Universal Dust Cleaner           0.039680
# Logitech MK345 Wireless combo                 0.038810
# SanDisk 32GB Ultra SDHC card                  0.037939
# YUNSONG 3pack 6ft Nylon Lightning Cable       0.037765
# Anker 2-in-1 USB Card Reader                  0.037243
# VicTsing Wireless mouse                       0.034981
# Mpow HC6 USB Headset                          0.034111
# Vsco 70 pack stickers                         0.033937
# iPhone SE case                                0.033763
# iPhone Charger Cable Anker 6ft                0.032892
# Micro Center 32GB Memory card                 0.031674
# Moread HDMI to VGA Adapter                    0.031500
# RUNMUS Gaming Headset                         0.031326
# nonda USB C to USB Adapter                    0.031152
# HP 62XL ink                                   0.029064
# Jelly Comb 2.4G Slim Wireless mouse           0.028194
# HP 952 ink                                    0.028019
# M.2 Screw kit                                 0.026801
# TP-Link AC1750 Smart WiFi Router              0.026279
# HP 63 Ink                                     0.026105
# HP 61 Tri-color ink                           0.025409
# PS4 Headset                                   0.025409
# 5pack Nylon Braided USB C cables              0.024017
# SanDisk Extreme Pro 128GB card                0.023843
# Brother Genuine High Yield Toner Cartridge    0.022450
# Dust-Off Compressed Gas                       0.021232
# Cat 6 Ethernet Cable 50ft                     0.020362
# Apple Lightning to USB cable                  0.020014
# Leader Desk Pad Protector                     0.019840
# iPhone 11 case                                0.018796
# SAMSUNG 128GB card                            0.018274
# AutoFocus 1080p Webcam                        0.017926
# SanDisk Ultra 400GB card                      0.017403
# Mfi-Certified Lightning to USB A Cable        0.017055
# SanDisk Extreme Pro 64GB card                 0.016533
# DisplayPort ot HDMI adapter                   0.015141
# SAMSUNG 256 GB card                           0.014967
# XPOWER A-2 Air Pump blower                    0.014445
# HP ENVY 5055 printer                          0.013749
# ARRIS SURFboard SB8200 Cable Modem            0.013575
# HP 63 Tri-color ink                           0.013575
# Creative Pebble 2.0 Speakers                  0.013401
# SanDisk Extreme 256GB card                    0.012704
# Microsot Surface Dock 2                       0.012356
# Anker 4-port USB hub                          0.011660
# HP 63XL Tri-color ink                         0.011660
# 10ft iPHone Charger Cable                     0.011486
# HP 902XL ink                                  0.011486
# seenda Wireless mouse                         0.011312
# hP 65 Tri-color ink                           0.011138
# SanDisk 128GB card                            0.011138
# USB C to USB Male Adapter                     0.010790
# CicTsing MM057 2.4G Wireless Mouse            0.010616
# HOVAMP iPhone charger                         0.010268
# HP 64 Tri-Color ink                           0.009920
# Sabrent 4-port USB 3.0 hub                    0.009920
# HP952XL ink                                   0.009398
# FEEL2NICE 5 pack 10ft Lighning cable          0.008702
# iPhone 12 Charger cable                       0.008702
# SanDisk Ultra 256GB card                      0.008180
# iPhone 12 Pro case                            0.008006
# SanDisk Extreme 128GB card                    0.007832
# Webcam with Microphone                        0.007832
# SanDisk 32GB card                             0.007658
# Apple Magic Mouse 2                           0.007483
# NETGEAR Nighthawk WiFi Router                 0.007309
# iPhone 12 case                                0.007135
# iFixit Pro Tech Toolkit                       0.006787
# 3 pack Nylon Braided Lightning Cable          0.006613
# SanDisk Extreme 32GB 2pack card               0.006439
# VicTsing Mouse Pad                            0.006091
# Blue Light Blocking Glasses 2pack             0.006091
# Logitech MK270 Wireless Keyboard/Mouse        0.005917
# HP 61 2 pack ink                              0.005743
# TONOR USB Gaming Microphone                   0.005743
# SAMSUNG EVO 64GB card                         0.005569
# TP-Link AC4000 WiFi router                    0.005569
# HP 64 ink                                     0.005569
# Blue Light Blocking Glasses                   0.005221
# NETGEAR CM500 Cable Modem                     0.005047
# UNEN Mfi Certified 5-pack Lightning Cable     0.005047
# HooToo USB C Hub                              0.005047
# Logitech USB H390 headset                     0.004699
# BENGOO G90000 headset                         0.002088
# Apple Pencil 2nd Gen                          0.001044
# Apple Power Adapter Extension Cable           0.000870
# NETGEAR Orbi Home Mesh WiFi System            0.000522
# dtype: float64

# %%
rules = list(permutations(basket_std.columns, 2))

# %%
frequent_itemsets = apriori(basket_std, 
                           min_support = 0.01,
                           max_len = 2,
                           use_colnames = True)

# %%
print(frequent_itemsets.sort_values('support', ascending=False))
# Out:
#       support                                           itemsets
# 21   0.294814                   (Dust-Off Compressed Gas 2 pack)
# 10   0.218935                                     (Apple Pencil)
# 75   0.218239                 (VIVO Dual LCD Monitor Desk mount)
# 27   0.201183                                        (HP 61 ink)
# 71   0.200139                            (USB 2.0 Printer cable)
# 66   0.163418                    (Screen Mom Screen Cleaner kit)
# 11   0.159763                        (Apple USB-C Charger cable)
# 65   0.124608                          (SanDisk Ultra 64GB card)
# 49   0.121128             (Nylon Braided Lightning to USB cable)
# 67   0.117299                              (Stylus Pen for iPad)
# 8    0.110338            (Apple Lightning to Digital AV Adapter)
# 68   0.100766                     (Syntech USB C to USB Adapter)
# 70   0.091890                     (TopMate C5 Laptop Cooler pad)
# 41   0.090672                     (Logitech M510 Wireless mouse)
# 7    0.085973                      (Anker USB C to HDMI Adapter)
# 32   0.085973                                      (HP 63XL Ink)
# 22   0.081796              (FEIYOLD Blue light Blocking Glasses)
# 15   0.079360                              (Cat8 Ethernet Cable)
# 63   0.079011                         (SanDisk Ultra 128GB card)
# 211  0.077967  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
# 23   0.076575                   (Falcon Dust Off Compressed Gas)
# 28   0.073268                            (HP 62XL Tri-Color ink)
# 187  0.068743        (HP 61 ink, Dust-Off Compressed Gas 2 pack)
# 133  0.066481     (Dust-Off Compressed Gas 2 pack, Apple Pencil)
# 74   0.066133                (USB Type C to USB-A Charger cable)
# 51   0.065437                          (Premium Nylon USB Cable)
# 55   0.064741                            (SAMSUNG EVO 32GB card)
# 1    0.064567                 (10ft iPHone Charger Cable 2 Pack)
# 205  0.062652  (Dust-Off Compressed Gas 2 pack, Screen Mom Sc...
# 56   0.060912               (SanDisk 128GB Ultra microSDXC card)
# 38   0.060738                     (HyperX Cloud Stinger Headset)
# 58   0.054125                     (SanDisk 128GB microSDXC card)
# 2    0.053428                   (3A USB Type C Cable 3 pack 6FT)
# 204  0.053428  (SanDisk Ultra 64GB card, Dust-Off Compressed ...
# 73   0.053254                                 (USB Type C Cable)
# 252  0.051166      (HP 61 ink, VIVO Dual LCD Monitor Desk mount)
# 309  0.051166  (SanDisk Ultra 64GB card, VIVO Dual LCD Monito...
# 153  0.047685   (VIVO Dual LCD Monitor Desk mount, Apple Pencil)
# 151  0.047511              (USB 2.0 Printer cable, Apple Pencil)
# 197  0.046641  (Dust-Off Compressed Gas 2 pack, Nylon Braided...
# 314  0.046293  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...
# 249  0.044901                 (HP 61 ink, USB 2.0 Printer cable)
# 210  0.044031  (USB 2.0 Printer cable, Dust-Off Compressed Ga...
# 206  0.044031  (Dust-Off Compressed Gas 2 pack, Stylus Pen fo...
# 136  0.043334                          (HP 61 ink, Apple Pencil)
# 34   0.042116                                        (HP 65 ink)
# 245  0.041942         (HP 61 ink, Screen Mom Screen Cleaner kit)
# 24   0.040898                 (HOVAMP Mfi 6pack Lightning Cable)
# 155  0.040376  (Dust-Off Compressed Gas 2 pack, Apple USB-C C...
# 147  0.040202      (Apple Pencil, Screen Mom Screen Cleaner kit)
# 17   0.039680              (Cleaning Gel Universal Dust Cleaner)
# 42   0.038810                    (Logitech MK345 Wireless combo)
# 59   0.037939                     (SanDisk 32GB Ultra SDHC card)
# 79   0.037765          (YUNSONG 3pack 6ft Nylon Lightning Cable)
# 117  0.037591  (Apple Lightning to Digital AV Adapter, Apple ...
# 170  0.037243  (USB 2.0 Printer cable, Apple USB-C Charger ca...
# 5    0.037243                     (Anker 2-in-1 USB Card Reader)
# 284  0.036373  (VIVO Dual LCD Monitor Desk mount, Nylon Braid...
# 325  0.036025  (USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 184  0.035851  (Dust-Off Compressed Gas 2 pack, FEIYOLD Blue ...
# 207  0.035851  (Dust-Off Compressed Gas 2 pack, Syntech USB C...
# 76   0.034981                          (VicTsing Wireless mouse)
# 173  0.034633  (VIVO Dual LCD Monitor Desk mount, Apple USB-C...
# 48   0.034111                             (Mpow HC6 USB Headset)
# 77   0.033937                            (Vsco 70 pack stickers)
# 83   0.033763                                   (iPhone SE case)
# 131  0.033241          (Apple Pencil, Apple USB-C Charger cable)
# 318  0.032892  (VIVO Dual LCD Monitor Desk mount, Stylus Pen ...
# 82   0.032892                   (iPhone Charger Cable Anker 6ft)
# 120  0.031848  (Apple Lightning to Digital AV Adapter, Dust-O...
# 107  0.031848  (Dust-Off Compressed Gas 2 pack, Anker USB C t...
# 45   0.031674                    (Micro Center 32GB Memory card)
# 47   0.031500                       (Moread HDMI to VGA Adapter)
# 52   0.031326                            (RUNMUS Gaming Headset)
# 209  0.031152  (Dust-Off Compressed Gas 2 pack, TopMate C5 La...
# 84   0.031152                       (nonda USB C to USB Adapter)
# 313  0.030978  (USB 2.0 Printer cable, Screen Mom Screen Clea...
# 279  0.030804  (Screen Mom Screen Cleaner kit, Nylon Braided ...
# 158  0.030630             (HP 61 ink, Apple USB-C Charger cable)
# 194  0.030630  (Dust-Off Compressed Gas 2 pack, Logitech M510...
# 244  0.030108               (SanDisk Ultra 64GB card, HP 61 ink)
# 87   0.030108  (Dust-Off Compressed Gas 2 pack, 10ft iPHone C...
# 237  0.029934  (HP 61 ink, Nylon Braided Lightning to USB cable)
# 224  0.029934  (VIVO Dual LCD Monitor Desk mount, FEIYOLD Blu...
# 185  0.029760  (Dust-Off Compressed Gas 2 pack, Falcon Dust O...
# 29   0.029064                                      (HP 62XL ink)
# 129  0.028716  (USB 2.0 Printer cable, Apple Lightning to Dig...
# 304  0.028716  (SanDisk Ultra 64GB card, Screen Mom Screen Cl...
# 148  0.028368                (Apple Pencil, Stylus Pen for iPad)
# 140  0.028368  (Apple Pencil, Nylon Braided Lightning to USB ...
# 39   0.028194              (Jelly Comb 2.4G Slim Wireless mouse)
# 130  0.028019  (Apple Lightning to Digital AV Adapter, VIVO D...
# 36   0.028019                                       (HP 952 ink)
# 274  0.027671  (VIVO Dual LCD Monitor Desk mount, Logitech M5...
# 116  0.027323  (VIVO Dual LCD Monitor Desk mount, Anker USB C...
# 43   0.026801                                    (M.2 Screw kit)
# 203  0.026279  (Dust-Off Compressed Gas 2 pack, SanDisk Ultra...
# 188  0.026279  (Dust-Off Compressed Gas 2 pack, HP 62XL Tri-C...
# 69   0.026279                 (TP-Link AC1750 Smart WiFi Router)
# 198  0.026279  (Dust-Off Compressed Gas 2 pack, Premium Nylon...
# 317  0.026279       (USB 2.0 Printer cable, Stylus Pen for iPad)
# 146  0.026105            (SanDisk Ultra 64GB card, Apple Pencil)
# 30   0.026105                                        (HP 63 Ink)
# 246  0.025931                   (HP 61 ink, Stylus Pen for iPad)
# 26   0.025409                              (HP 61 Tri-color ink)
# 50   0.025409                                      (PS4 Headset)
# 132  0.025409                (Cat8 Ethernet Cable, Apple Pencil)
# 175  0.025061  (Cat8 Ethernet Cable, Dust-Off Compressed Gas ...
# 283  0.024887  (USB 2.0 Printer cable, Nylon Braided Lightnin...
# 149  0.024887       (Syntech USB C to USB Adapter, Apple Pencil)
# 3    0.024017                 (5pack Nylon Braided USB C cables)
# 61   0.023843                   (SanDisk Extreme Pro 128GB card)
# 320  0.023669  (VIVO Dual LCD Monitor Desk mount, Syntech USB...
# 236  0.023495          (HP 61 ink, Logitech M510 Wireless mouse)
# 126  0.023321  (Apple Lightning to Digital AV Adapter, Screen...
# 319  0.023321  (USB 2.0 Printer cable, Syntech USB C to USB A...
# 234  0.022973                           (HP 63XL Ink, HP 61 ink)
# 167  0.022973  (Screen Mom Screen Cleaner kit, Apple USB-C Ch...
# 271  0.022973  (Screen Mom Screen Cleaner kit, Logitech M510 ...
# 199  0.022798  (Dust-Off Compressed Gas 2 pack, SAMSUNG EVO 3...
# 118  0.022798  (Apple Lightning to Digital AV Adapter, Apple ...
# 13   0.022450       (Brother Genuine High Yield Toner Cartridge)
# 231  0.022450  (Falcon Dust Off Compressed Gas, VIVO Dual LCD...
# 121  0.022276  (HP 61 ink, Apple Lightning to Digital AV Adap...
# 190  0.022276      (HP 63XL Ink, Dust-Off Compressed Gas 2 pack)
# 200  0.022276  (SanDisk 128GB Ultra microSDXC card, Dust-Off ...
# 221  0.022276  (FEIYOLD Blue light Blocking Glasses, Screen M...
# 278  0.022102  (SanDisk Ultra 64GB card, Nylon Braided Lightn...
# 95   0.022102  (Dust-Off Compressed Gas 2 pack, 3A USB Type C...
# 150  0.021928       (TopMate C5 Laptop Cooler pad, Apple Pencil)
# 269  0.021754  (Logitech M510 Wireless mouse, Nylon Braided L...
# 310  0.021580  (Stylus Pen for iPad, Screen Mom Screen Cleane...
# 293  0.021580  (VIVO Dual LCD Monitor Desk mount, SAMSUNG EVO...
# 182  0.021580  (Cat8 Ethernet Cable, VIVO Dual LCD Monitor De...
# 262  0.021406               (HP 63XL Ink, USB 2.0 Printer cable)
# 217  0.021406   (HP 61 ink, FEIYOLD Blue light Blocking Glasses)
# 168  0.021406   (Stylus Pen for iPad, Apple USB-C Charger cable)
# 296  0.021232  (SanDisk 128GB Ultra microSDXC card, VIVO Dual...
# 20   0.021232                          (Dust-Off Compressed Gas)
# 110  0.021058  (Anker USB C to HDMI Adapter, Nylon Braided Li...
# 294  0.020884  (SanDisk Ultra 64GB card, SanDisk 128GB Ultra ...
# 289  0.020710  (VIVO Dual LCD Monitor Desk mount, Premium Nyl...
# 14   0.020362                        (Cat 6 Ethernet Cable 50ft)
# 303  0.020362  (VIVO Dual LCD Monitor Desk mount, SanDisk Ult...
# 9    0.020014                     (Apple Lightning to USB cable)
# 322  0.019840  (VIVO Dual LCD Monitor Desk mount, TopMate C5 ...
# 92   0.019840  (Screen Mom Screen Cleaner kit, 10ft iPHone Ch...
# 40   0.019840                        (Leader Desk Pad Protector)
# 192  0.019492  (Dust-Off Compressed Gas 2 pack, HyperX Cloud ...
# 243  0.019492              (HP 61 ink, SanDisk Ultra 128GB card)
# 166  0.019318  (SanDisk Ultra 64GB card, Apple USB-C Charger ...
# 228  0.019318  (Falcon Dust Off Compressed Gas, Screen Mom Sc...
# 248  0.019318          (HP 61 ink, TopMate C5 Laptop Cooler pad)
# 225  0.019144        (HP 61 ink, Falcon Dust Off Compressed Gas)
# 305  0.018970     (SanDisk Ultra 64GB card, Stylus Pen for iPad)
# 302  0.018970  (USB 2.0 Printer cable, SanDisk Ultra 128GB card)
# 81   0.018796                                   (iPhone 11 case)
# 163  0.018796  (Apple USB-C Charger cable, Nylon Braided Ligh...
# 135  0.018796     (Falcon Dust Off Compressed Gas, Apple Pencil)
# 300  0.018622  (SanDisk Ultra 128GB card, Screen Mom Screen C...
# 93   0.018622  (VIVO Dual LCD Monitor Desk mount, 10ft iPHone...
# 220  0.018448  (SanDisk Ultra 64GB card, FEIYOLD Blue light B...
# 139  0.018448       (Apple Pencil, Logitech M510 Wireless mouse)
# 169  0.018448  (Syntech USB C to USB Adapter, Apple USB-C Cha...
# 258  0.018448  (VIVO Dual LCD Monitor Desk mount, HP 62XL Tri...
# 108  0.018274           (HP 61 ink, Anker USB C to HDMI Adapter)
# 263  0.018274    (HP 63XL Ink, VIVO Dual LCD Monitor Desk mount)
# 112  0.018274  (Screen Mom Screen Cleaner kit, Anker USB C to...
# 53   0.018274                               (SAMSUNG 128GB card)
# 308  0.018100   (SanDisk Ultra 64GB card, USB 2.0 Printer cable)
# 12   0.017926                           (AutoFocus 1080p Webcam)
# 247  0.017751          (HP 61 ink, Syntech USB C to USB Adapter)
# 238  0.017751               (HP 61 ink, Premium Nylon USB Cable)
# 99   0.017577  (VIVO Dual LCD Monitor Desk mount, 3A USB Type...
# 280  0.017577  (Stylus Pen for iPad, Nylon Braided Lightning ...
# 64   0.017403                         (SanDisk Ultra 400GB card)
# 201  0.017403  (Dust-Off Compressed Gas 2 pack, SanDisk 128GB...
# 321  0.017403  (USB 2.0 Printer cable, TopMate C5 Laptop Cool...
# 324  0.017403  (USB 2.0 Printer cable, USB Type C to USB-A Ch...
# 311  0.017403  (Syntech USB C to USB Adapter, Screen Mom Scre...
# 312  0.017229  (TopMate C5 Laptop Cooler pad, Screen Mom Scre...
# 44   0.017055           (Mfi-Certified Lightning to USB A Cable)
# 62   0.016533                    (SanDisk Extreme Pro 64GB card)
# 143  0.016359  (SanDisk 128GB Ultra microSDXC card, Apple Pen...
# 106  0.016011  (Anker USB C to HDMI Adapter, Apple USB-C Char...
# 105  0.016011        (Apple Pencil, Anker USB C to HDMI Adapter)
# 233  0.015663                 (HP 61 ink, HP 62XL Tri-Color ink)
# 134  0.015663  (FEIYOLD Blue light Blocking Glasses, Apple Pe...
# 172  0.015663  (Apple USB-C Charger cable, USB Type C to USB-...
# 115  0.015663  (USB 2.0 Printer cable, Anker USB C to HDMI Ad...
# 125  0.015663  (SanDisk Ultra 64GB card, Apple Lightning to D...
# 268  0.015489  (VIVO Dual LCD Monitor Desk mount, HyperX Clou...
# 255  0.015489  (Screen Mom Screen Cleaner kit, HP 62XL Tri-Co...
# 315  0.015489  (Syntech USB C to USB Adapter, Stylus Pen for ...
# 157  0.015489  (Falcon Dust Off Compressed Gas, Apple USB-C C...
# 154  0.015489   (Cat8 Ethernet Cable, Apple USB-C Charger cable)
# 141  0.015315            (Apple Pencil, Premium Nylon USB Cable)
# 111  0.015315  (SanDisk Ultra 64GB card, Anker USB C to HDMI ...
# 19   0.015141                      (DisplayPort ot HDMI adapter)
# 250  0.015141                      (HP 61 ink, USB Type C Cable)
# 54   0.014967                              (SAMSUNG 256 GB card)
# 191  0.014967        (Dust-Off Compressed Gas 2 pack, HP 65 ink)
# 128  0.014967  (Apple Lightning to Digital AV Adapter, Syntec...
# 286  0.014967  (Screen Mom Screen Cleaner kit, Premium Nylon ...
# 270  0.014967  (SanDisk Ultra 64GB card, Logitech M510 Wirele...
# 290  0.014793   (SanDisk Ultra 64GB card, SAMSUNG EVO 32GB card)
# 219  0.014793  (FEIYOLD Blue light Blocking Glasses, Nylon Br...
# 162  0.014793  (Apple USB-C Charger cable, Logitech M510 Wire...
# 179  0.014793  (Cat8 Ethernet Cable, Screen Mom Screen Cleane...
# 176  0.014793                   (HP 61 ink, Cat8 Ethernet Cable)
# 109  0.014619  (Anker USB C to HDMI Adapter, Logitech M510 Wi...
# 230  0.014445  (USB 2.0 Printer cable, Falcon Dust Off Compre...
# 145  0.014445           (SanDisk Ultra 128GB card, Apple Pencil)
# 165  0.014445  (SanDisk Ultra 128GB card, Apple USB-C Charger...
# 78   0.014445                       (XPOWER A-2 Air Pump blower)
# 138  0.014445                        (HP 63XL Ink, Apple Pencil)
# 212  0.014271  (VicTsing Wireless mouse, Dust-Off Compressed ...
# 239  0.014271                 (HP 61 ink, SAMSUNG EVO 32GB card)
# 137  0.014271              (Apple Pencil, HP 62XL Tri-Color ink)
# 222  0.014097  (FEIYOLD Blue light Blocking Glasses, Stylus P...
# 181  0.013923       (Cat8 Ethernet Cable, USB 2.0 Printer cable)
# 96   0.013923        (HP 61 ink, 3A USB Type C Cable 3 pack 6FT)
# 119  0.013923  (Cat8 Ethernet Cable, Apple Lightning to Digit...
# 37   0.013749                             (HP ENVY 5055 printer)
# 124  0.013749  (Apple Lightning to Digital AV Adapter, Nylon ...
# 272  0.013749  (Stylus Pen for iPad, Logitech M510 Wireless m...
# 127  0.013749  (Apple Lightning to Digital AV Adapter, Stylus...
# 257  0.013749     (USB 2.0 Printer cable, HP 62XL Tri-Color ink)
# 152  0.013749  (Apple Pencil, USB Type C to USB-A Charger cable)
# 251  0.013575     (HP 61 ink, USB Type C to USB-A Charger cable)
# 4    0.013575               (ARRIS SURFboard SB8200 Cable Modem)
# 292  0.013575     (USB 2.0 Printer cable, SAMSUNG EVO 32GB card)
# 31   0.013575                              (HP 63 Tri-color ink)
# 281  0.013401  (Syntech USB C to USB Adapter, Nylon Braided L...
# 327  0.013401  (VicTsing Wireless mouse, VIVO Dual LCD Monito...
# 214  0.013401  (Dust-Off Compressed Gas 2 pack, iPhone Charge...
# 18   0.013401                     (Creative Pebble 2.0 Speakers)
# 282  0.013227  (TopMate C5 Laptop Cooler pad, Nylon Braided L...
# 89   0.013227      (HP 61 ink, 10ft iPHone Charger Cable 2 Pack)
# 277  0.013053  (SanDisk Ultra 128GB card, Nylon Braided Light...
# 273  0.013053  (USB 2.0 Printer cable, Logitech M510 Wireless...
# 156  0.012879  (FEIYOLD Blue light Blocking Glasses, Apple US...
# 113  0.012879  (Stylus Pen for iPad, Anker USB C to HDMI Adap...
# 102  0.012879  (Screen Mom Screen Cleaner kit, Anker 2-in-1 U...
# 328  0.012879  (VIVO Dual LCD Monitor Desk mount, iPhone SE c...
# 60   0.012704                       (SanDisk Extreme 256GB card)
# 91   0.012704  (SanDisk Ultra 64GB card, 10ft iPHone Charger ...
# 98   0.012704  (Screen Mom Screen Cleaner kit, 3A USB Type C ...
# 307  0.012530  (SanDisk Ultra 64GB card, TopMate C5 Laptop Co...
# 186  0.012530  (HOVAMP Mfi 6pack Lightning Cable, Dust-Off Co...
# 180  0.012530         (Cat8 Ethernet Cable, Stylus Pen for iPad)
# 100  0.012530  (Dust-Off Compressed Gas 2 pack, Anker 2-in-1 ...
# 316  0.012356  (TopMate C5 Laptop Cooler pad, Stylus Pen for ...
# 227  0.012356  (SanDisk Ultra 64GB card, Falcon Dust Off Comp...
# 213  0.012356  (Dust-Off Compressed Gas 2 pack, YUNSONG 3pack...
# 46   0.012356                          (Microsot Surface Dock 2)
# 183  0.012356  (Cleaning Gel Universal Dust Cleaner, Dust-Off...
# 241  0.012356          (HP 61 ink, SanDisk 128GB microSDXC card)
# 323  0.012182          (USB 2.0 Printer cable, USB Type C Cable)
# 276  0.012008  (VIVO Dual LCD Monitor Desk mount, Mpow HC6 US...
# 297  0.012008  (SanDisk 128GB microSDXC card, Screen Mom Scre...
# 223  0.012008  (USB 2.0 Printer cable, FEIYOLD Blue light Blo...
# 196  0.012008  (Dust-Off Compressed Gas 2 pack, Mpow HC6 USB ...
# 161  0.012008  (HyperX Cloud Stinger Headset, Apple USB-C Cha...
# 195  0.012008  (Logitech MK345 Wireless combo, Dust-Off Compr...
# 295  0.012008  (SanDisk 128GB Ultra microSDXC card, Screen Mo...
# 178  0.012008     (SanDisk Ultra 64GB card, Cat8 Ethernet Cable)
# 299  0.011834  (VIVO Dual LCD Monitor Desk mount, SanDisk 128...
# 240  0.011834    (HP 61 ink, SanDisk 128GB Ultra microSDXC card)
# 301  0.011834    (SanDisk Ultra 128GB card, Stylus Pen for iPad)
# 142  0.011834              (Apple Pencil, SAMSUNG EVO 32GB card)
# 229  0.011834  (Falcon Dust Off Compressed Gas, Stylus Pen fo...
# 159  0.011834  (HP 62XL Tri-Color ink, Apple USB-C Charger ca...
# 86   0.011834   (Apple Pencil, 10ft iPHone Charger Cable 2 Pack)
# 253  0.011834  (HP 62XL Tri-Color ink, Nylon Braided Lightnin...
# 6    0.011660                             (Anker 4-port USB hub)
# 33   0.011660                            (HP 63XL Tri-color ink)
# 122  0.011660  (Apple Lightning to Digital AV Adapter, HP 62X...
# 226  0.011660  (Falcon Dust Off Compressed Gas, Nylon Braided...
# 160  0.011660           (HP 63XL Ink, Apple USB-C Charger cable)
# 97   0.011660  (SanDisk Ultra 64GB card, 3A USB Type C Cable ...
# 267  0.011660  (USB 2.0 Printer cable, HyperX Cloud Stinger H...
# 88   0.011660  (FEIYOLD Blue light Blocking Glasses, 10ft iPH...
# 0    0.011486                        (10ft iPHone Charger Cable)
# 193  0.011486  (Dust-Off Compressed Gas 2 pack, Jelly Comb 2....
# 177  0.011486  (Cat8 Ethernet Cable, Nylon Braided Lightning ...
# 35   0.011486                                     (HP 902XL ink)
# 123  0.011486  (Apple Lightning to Digital AV Adapter, Logite...
# 103  0.011486  (VIVO Dual LCD Monitor Desk mount, Anker 2-in-...
# 85   0.011312                            (seenda Wireless mouse)
# 144  0.011312       (SanDisk 128GB microSDXC card, Apple Pencil)
# 275  0.011312  (Logitech MK345 Wireless combo, VIVO Dual LCD ...
# 80   0.011138                              (hP 65 Tri-color ink)
# 57   0.011138                               (SanDisk 128GB card)
# 285  0.010964  (SanDisk Ultra 64GB card, Premium Nylon USB Ca...
# 114  0.010964  (Syntech USB C to USB Adapter, Anker USB C to ...
# 94   0.010790     (Apple Pencil, 3A USB Type C Cable 3 pack 6FT)
# 260  0.010790             (SanDisk Ultra 64GB card, HP 63XL Ink)
# 242  0.010790          (HP 61 ink, SanDisk 32GB Ultra SDHC card)
# 298  0.010790  (USB 2.0 Printer cable, SanDisk 128GB microSDX...
# 72   0.010790                        (USB C to USB Male Adapter)
# 171  0.010790      (USB Type C Cable, Apple USB-C Charger cable)
# 215  0.010790   (Dust-Off Compressed Gas 2 pack, iPhone SE case)
# 189  0.010790      (HP 62XL ink, Dust-Off Compressed Gas 2 pack)
# 104  0.010790  (Apple Lightning to Digital AV Adapter, Anker ...
# 16   0.010616               (CicTsing MM057 2.4G Wireless Mouse)
# 306  0.010616  (SanDisk Ultra 64GB card, Syntech USB C to USB...
# 254  0.010616   (SanDisk Ultra 64GB card, HP 62XL Tri-Color ink)
# 265  0.010442      (VIVO Dual LCD Monitor Desk mount, HP 65 ink)
# 326  0.010442  (VIVO Dual LCD Monitor Desk mount, USB Type C ...
# 218  0.010442  (FEIYOLD Blue light Blocking Glasses, Logitech...
# 235  0.010442          (HP 61 ink, HyperX Cloud Stinger Headset)
# 101  0.010442  (FEIYOLD Blue light Blocking Glasses, Anker 2-...
# 90   0.010442  (10ft iPHone Charger Cable 2 Pack, Nylon Braid...
# 264  0.010442                 (USB 2.0 Printer cable, HP 65 ink)
# 164  0.010268  (Apple USB-C Charger cable, SAMSUNG EVO 32GB c...
# 232  0.010268  (HOVAMP Mfi 6pack Lightning Cable, USB 2.0 Pri...
# 25   0.010268                            (HOVAMP iPhone charger)
# 287  0.010268     (Stylus Pen for iPad, Premium Nylon USB Cable)
# 288  0.010268   (USB 2.0 Printer cable, Premium Nylon USB Cable)
# 291  0.010268  (Screen Mom Screen Cleaner kit, SAMSUNG EVO 32...
# 266  0.010094  (HyperX Cloud Stinger Headset, Screen Mom Scre...
# 202  0.010094  (Dust-Off Compressed Gas 2 pack, SanDisk Extre...
# 208  0.010094  (Dust-Off Compressed Gas 2 pack, TP-Link AC175...
# 259  0.010094    (HP 62XL ink, VIVO Dual LCD Monitor Desk mount)
# 256  0.010094  (Syntech USB C to USB Adapter, HP 62XL Tri-Col...
# 174  0.010094  (Dust-Off Compressed Gas 2 pack, Brother Genui...
# 216  0.010094  (Dust-Off Compressed Gas 2 pack, nonda USB C t...
# 261  0.010094       (HP 63XL Ink, Screen Mom Screen Cleaner kit)

# %%
rules = association_rules(frequent_itemsets,
                           metric = 'support',
                           min_threshold = 0.0015)

# %%
rules.head()
# Out:
#                              antecedents                         consequents  \
# 0                         (Apple Pencil)  (10ft iPHone Charger Cable 2 Pack)
# 1     (10ft iPHone Charger Cable 2 Pack)                      (Apple Pencil)
# 2       (Dust-Off Compressed Gas 2 pack)  (10ft iPHone Charger Cable 2 Pack)
# 3     (10ft iPHone Charger Cable 2 Pack)    (Dust-Off Compressed Gas 2 pack)
# 4  (FEIYOLD Blue light Blocking Glasses)  (10ft iPHone Charger Cable 2 Pack)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.218935            0.064567  0.011834    0.054054  0.837182
# 1            0.064567            0.218935  0.011834    0.183288  0.837182
# 2            0.294814            0.064567  0.030108    0.102125  1.581701
# 3            0.064567            0.294814  0.030108    0.466307  1.581701
# 4            0.081796            0.064567  0.011660    0.142553  2.207845
#
#    leverage  conviction
# 0 -0.002302    0.988887
# 1 -0.002302    0.956354
# 2  0.011073    1.041830
# 3  0.011073    1.321334
# 4  0.006379    1.090952

# %%
BREAK
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-66db536c6cae> in <module>
# ----> 1 BREAK
#
# NameError: name 'BREAK' is not defined

# %%
# Convert teleco dataframe to a list of lists
transactions = teleco_df.values.tolist()

# %%
flattened = [i for t in transactions for i in t]
items = list(set(flattened))

# %%
# items = [ i for t in transactions for i in t if not(pd.isnull(i)) == True]

# %%
rules = list(permutations(items, 2))

# %%
print('There are {} rules from the observed dataset.'.format(len(rules)))

# %%
# new_list = [item for item in transactions if str(item) != 'nan']

new_list = [item for transaction in transactions for item in transaction if str(item) != 'nan']

# %%
new_list[0] = 'test'

# %%
new_list = []
counter = 0

for transaction in transactions:
    print(transaction)
    for item in transaction:
        print(item)
    print(counter)
    counter += 1

# %%
print(transactions)

# %%
encoder = TransactionEncoder().fit(transactions)

# %%
onehot = encoder.transform(transactions)

# %%
onehot = pd.DataFrame(onehot, columns = encoder.columns_)

# %%
onehot.head()
